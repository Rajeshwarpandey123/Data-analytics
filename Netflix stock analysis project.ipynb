# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime

# %%
df2=pd.read_csv("Netflix.csv")

# %%
df2
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 1     2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2     2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 3     2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 4     2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...          ...         ...         ...         ...         ...         ...
# 4869  2021-09-24  592.500000  592.979980  583.640015  592.390015  592.390015
# 4870  2021-09-27  587.950012  593.580017  576.929993  592.640015  592.640015
# 4871  2021-09-28  589.000000  599.539978  580.159973  583.849976  583.849976
# 4872  2021-09-29  589.010010  609.880005  588.010010  599.059998  599.059998
# 4873  2021-09-30  608.049988  619.000000  608.049988  610.340027  610.340027
#
#          Volume
# 0     104790000
# ...

# %%
df2.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close     Volume
# 0  2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 1  2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2  2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 3  2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 4  2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.set(rc={"figure.figsize":(10,5)})

# %%
df2["Date"]=pd.to_datetime(df2["Date"])
df2=df2.set_index('Date')
df2.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2002-05-23  1.156429  1.242857  1.145714  1.196429   1.196429  104790000
# 2002-05-24  1.214286  1.225000  1.197143  1.210000   1.210000   11104800
# 2002-05-28  1.213571  1.232143  1.157143  1.157143   1.157143    6609400
# 2002-05-29  1.164286  1.164286  1.085714  1.103571   1.103571    6757800
# 2002-05-30  1.107857  1.107857  1.071429  1.071429   1.071429   10154200

# %%
sns.lineplot(x=df2.index,y=df2["Volume"],label="Volume")
plt.title("Volume of stock vs time")
# Out:
# Text(0.5, 1.0, 'Volume of stock vs time')

# %%
df2.plot(y=["High",'Open',"Close"],title="Netflix stock price")
# Out:
# <Axes: title={'center': 'Netflix stock price'}, xlabel='Date'>

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,figsize=(15,10))
df2.groupby(df2.index.day).mean().plot(y="Volume",ax=ax1,xlabel='Day')
df2.groupby(df2.index.month).mean().plot(y="Volume",ax=ax2,xlabel='Month')
df2.groupby(df2.index.year).mean().plot(y="Volume",ax=ax3,xlabel='Year')
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # Dates with highest stock price.

# %%
df2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...                ...         ...         ...         ...         ...
# 2021-09-24  592.500000  592.979980  583.640015  592.390015  592.390015
# 2021-09-27  587.950012  593.580017  576.929993  592.640015  592.640015
# 2021-09-28  589.000000  599.539978  580.159973  583.849976  583.849976
# 2021-09-29  589.010010  609.880005  588.010010  599.059998  599.059998
# 2021-09-30  608.049988  619.000000  608.049988  610.340027  610.340027
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# ...

# %% [markdown]
# # Top 5 dates with highest stock price.

# %%
a=df2.sort_values(by="High",ascending=False).head(5)
a['High']
# Out:
# Date
# 2021-09-30    619.000000
# 2021-09-08    615.599976
# 2021-09-07    613.849976
# 2021-09-29    609.880005
# 2021-09-10    609.450012
# Name: High, dtype: float64

# %%
a=df2.sort_values('Low',descending=True).head(5)
a["Low"]
# Out:
# Date
# 2002-10-10    0.346429
# 2002-10-09    0.347143
# 2002-10-07    0.382143
# 2002-10-08    0.390714
# 2002-10-16    0.442857
# Name: Low, dtype: float64

# %% [markdown]
# # Top-5 dates with lowest stock price

# %%
df2
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2002-05-23    1.156429    1.242857    1.145714    1.196429    1.196429
# 2002-05-24    1.214286    1.225000    1.197143    1.210000    1.210000
# 2002-05-28    1.213571    1.232143    1.157143    1.157143    1.157143
# 2002-05-29    1.164286    1.164286    1.085714    1.103571    1.103571
# 2002-05-30    1.107857    1.107857    1.071429    1.071429    1.071429
# ...                ...         ...         ...         ...         ...
# 2021-09-24  592.500000  592.979980  583.640015  592.390015  592.390015
# 2021-09-27  587.950012  593.580017  576.929993  592.640015  592.640015
# 2021-09-28  589.000000  599.539978  580.159973  583.849976  583.849976
# 2021-09-29  589.010010  609.880005  588.010010  599.059998  599.059998
# 2021-09-30  608.049988  619.000000  608.049988  610.340027  610.340027
#
#                Volume
# Date
# 2002-05-23  104790000
# 2002-05-24   11104800
# 2002-05-28    6609400
# ...

# %%
b=df2.sort_values("Low",ascending=True).head(5)
b["Low"]
# Out:
# Date
# 2002-10-10    0.346429
# 2002-10-09    0.347143
# 2002-10-07    0.382143
# 2002-10-08    0.390714
# 2002-10-16    0.442857
# Name: Low, dtype: float64

# %%
fig,axes=plt.subplots(nrows=1,ncols=2,sharex=True,figsize = (12,5))
fig.suptitle("High and low values stock per period of time ")
sns.lineplot(ax=axes[0],y=df2["High"],x=df2.index,color="green")
sns.lineplot(ax=axes[1],y=df2["Low"],x=df2.index,color='red')
# Out:
# <Axes: xlabel='Date', ylabel='Low'>
